# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
merged_personal_df = pd.read_csv("./Resources/merged_personal_df.csv")

# %%
merged_personal_df
# Out:
#      Unnamed: 0  Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0             0  2014    95608     60729.0         8301.0         13.67
# 1             1  2014    95610     43572.0         7174.0         16.46
# 2             2  2014    95621     41474.0         5842.0         14.09
# 3             3  2014    95624     63131.0         6848.0         10.85
# 4             4  2014    95626      6335.0          792.0         12.50
# ..          ...   ...      ...         ...            ...           ...
# 240         240  2018    95838     39187.0         9989.0         25.49
# 241         241  2018    95841     20586.0         3964.0         19.26
# 242         242  2018    95842     32269.0         7050.0         21.85
# 243         243  2018    95843     46709.0         5818.0         12.46
# 244         244  2018    95864     23733.0         1720.0          7.25
#
#      Family Poverty Count  Median Household Income  Per Capita Income  \
# ...

# %%
mp2014_df = merged_personal_df.loc[(merged_personal_df["Year"] == 2014)]
mp2015_df = merged_personal_df.loc[(merged_personal_df["Year"] == 2015)]

# %%
# convert crime count to crime rate
# crime rate vs home value
# crime rate vs poverty rate
# per year
# 10 graphs

# %%
population1 = mp2014_df["PC"]
population2 = mp2015_df["PC"]
plt.subplot(2, 1, 2)
plt.hist(population1, 49, density=True, alpha=0.7, label="population1")
plt.hist(population2, 49, density=True, alpha=0.7, label="population2")
plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
