# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
a = Census(api_key, year=2014)
b = Census(api_key, year=2015)
c = Census(api_key, year=2016)
d = Census(api_key, year=2017)
e = Census(api_key, year=2018)
f = Census(api_key, year=2019)

# %%
# Median Household Income
# "B19013_001E"
# Median household income in the past 12 months

# Income Per Capita
# "B19301_001E"
# Per capita income in the past 12 months

# Poverty Count
# "B17001_002E"
# Number of persons whose income in the past 12 months is below the poverty level

# Family Poverty Count
# "B17012_002E"
# Number of families below the poverty level in the past 12 months

# Population
# "B01003_001E"
# Total population

# Median Home Value
# "B25077_001E"
# average value of an owner-occupied home

# %%
# Run Census Search to retrieve data on all zip codes (2014)
census_data_a = a.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
                          "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd_a = pd.DataFrame(census_data_a)

# Column Reordering
census_pd_a = census_pd_a.rename(columns={
    "B01003_001E": "Population", 
    "B17001_002E": "Poverty Count", 
    "B17012_002E": "Family Poverty Count",
    "B19013_001E": "Median Household Income", 
    "B19301_001E": "Per Capita Income", 
    "B25077_001E": "Median Home Value",
    "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd_a["Poverty Rate"] = (100 * census_pd_a["Poverty Count"].astype(float) / census_pd_a["Population"].astype(float)).round(2)

# Final DataFrame
census_pd_a = census_pd_a[[
    "Zipcode", 
    "Population", 
    "Poverty Count", 
    "Poverty Rate", 
    "Family Poverty Count", 
    "Median Household Income", 
    "Per Capita Income", 
    "Median Home Value"]]

# Filter Zipcode: limited to Sac County
census_sac_a = census_pd_a[census_pd_a["Zipcode"].isin([
    "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
    "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
    "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
    "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
    "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
    "95841", "95842", "95843", "95864"])]

# Visualize
print(len(census_sac_a))
census_sac_a
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-61-dd07667be7fe> in <module>
#       1 # Run Census Search to retrieve data on all zip codes (2014)
# ----> 2 census_data_a = a.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
#       3                           "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})
#       4
#       5 # Convert to DataFrame
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     275         self._switch_endpoints(kwargs.get('year', self.default_year))
#     276
# --> 277         return super(ACSClient, self).get(*args, **kwargs)
#     278
#     279 class ACS5Client(ACSClient):
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
# --> 134         merged_results = [merge(result) for result in zip(*all_results)]
#     135
#     136         return merged_results
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in <genexpr>(.0)
#     130
#     131     def get(self, fields, geo, year=None, **kwargs):
# --> 132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
#     134         merged_results = [merge(result) for result in zip(*all_results)]
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in query(self, fields, geo, year, **kwargs)
#     177
#     178         else:
# --> 179             raise CensusException(resp.text)
#     180
#     181     @lru_cache(maxsize=1024)
#
# CensusException: <html><head><title>Error report</title></head><body><h1>HTTP Status 404 - /data/2014/acs5</h1></body></html>

# %%
# Run Census Search to retrieve data on all zip codes (2015)
census_data_b = b.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
                          "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd_b = pd.DataFrame(census_data_b)

# Column Reordering
census_pd_b = census_pd_b.rename(columns={
    "B01003_001E": "Population", 
    "B17001_002E": "Poverty Count", 
    "B17012_002E": "Family Poverty Count",
    "B19013_001E": "Median Household Income", 
    "B19301_001E": "Per Capita Income", 
    "B25077_001E": "Median Home Value",
    "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd_b["Poverty Rate"] = (100 * census_pd_b["Poverty Count"].astype(float) / census_pd_b["Population"].astype(float)).round(2)

# Final DataFrame
census_pd_b = census_pd_b[[
    "Zipcode", 
    "Population", 
    "Poverty Count", 
    "Poverty Rate", 
    "Family Poverty Count", 
    "Median Household Income", 
    "Per Capita Income", 
    "Median Home Value"]]

# Filter Zipcode: limited to Sac County
census_sac_b = census_pd_b[census_pd_b["Zipcode"].isin([
    "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
    "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
    "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
    "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
    "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
    "95841", "95842", "95843", "95864"])]


# Visualize
print(len(census_sac_b))
census_sac_b
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-48-7165e2d9911b> in <module>
#       1 # Run Census Search to retrieve data on all zip codes (2015)
# ----> 2 census_data_b = b.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
#       3                           "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})
#       4
#       5 # Convert to DataFrame
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     275         self._switch_endpoints(kwargs.get('year', self.default_year))
#     276
# --> 277         return super(ACSClient, self).get(*args, **kwargs)
#     278
#     279 class ACS5Client(ACSClient):
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
# --> 134         merged_results = [merge(result) for result in zip(*all_results)]
#     135
#     136         return merged_results
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in <genexpr>(.0)
#     130
#     131     def get(self, fields, geo, year=None, **kwargs):
# --> 132         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     133                        for fifty_fields in chunks(fields, 50))
#     134         merged_results = [merge(result) for result in zip(*all_results)]
#
# ~\anaconda3\envs\datavispip\lib\site-packages\census\core.py in query(self, fields, geo, year, **kwargs)
#     177
#     178         else:
# --> 179             raise CensusException(resp.text)
#     180
#     181     @lru_cache(maxsize=1024)
#
# CensusException: <html><head><title>Error report</title></head><body><h1>HTTP Status 404 - /data/2015/acs5</h1></body></html>

# %%
# Run Census Search to retrieve data on all zip codes (2016)
census_data_c = c.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
                          "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd_c = pd.DataFrame(census_data_c)

# Column Reordering
census_pd_c = census_pd_c.rename(columns={
    "B01003_001E": "Population", 
    "B17001_002E": "Poverty Count", 
    "B17012_002E": "Family Poverty Count",
    "B19013_001E": "Median Household Income", 
    "B19301_001E": "Per Capita Income", 
    "B25077_001E": "Median Home Value",
    "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd_c["Poverty Rate"] = (100 * census_pd_c["Poverty Count"].astype(float) / census_pd_c["Population"].astype(float)).round(2)

# Final DataFrame
census_pd_c = census_pd_c[[
    "Zipcode", 
    "Population", 
    "Poverty Count", 
    "Poverty Rate", 
    "Family Poverty Count", 
    "Median Household Income", 
    "Per Capita Income", 
    "Median Home Value"]]

# Filter Zipcode: limited to Sac County
census_sac_c = census_pd_c[census_pd_c["Zipcode"].isin([
    "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
    "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
    "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
    "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
    "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
    "95841", "95842", "95843", "95864"])]

# Label year of 2016 to Zipcodes
census_sac_c["Zipcode"] = "2016-" + census_sac_c["Zipcode"].astype(str)

# Drop bad data
# (Removed 95652, 95680)
# (Removed 95615 to align with 2018)
census_sac_c = census_sac_c.dropna(how='any')
census_sac_c = census_sac_c.loc[(census_sac_c["Median Home Value"] > -666666666)]
census_sac_c = census_sac_c.loc[(census_sac_c["Median Household Income"] > -666666666)]
census_sac_c = census_sac_c.loc[(census_sac_c["Zipcode"] != "95615")]

# Visualize
print(len(census_sac_c))
census_sac_c
# Out:
# 52
#           Zipcode  Population  Poverty Count  Poverty Rate  \
    "B17001_002E": "Poverty Count", 
    "B17012_002E": "Family Poverty Count",
    "B19013_001E": "Median Household Income", 
    "B19301_001E": "Per Capita Income", 
    "B25077_001E": "Median Home Value",
    "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd_d["Poverty Rate"] = (100 * census_pd_d["Poverty Count"].astype(float) / census_pd_d["Population"].astype(float)).round(2)

# Final DataFrame
census_pd_d = census_pd_d[[
    "Zipcode", 
    "Population", 
    "Poverty Count", 
    "Poverty Rate", 
    "Family Poverty Count", 
    "Median Household Income", 
    "Per Capita Income", 
    "Median Home Value"]]

# Filter Zipcode: limited to Sac County
census_sac_d = census_pd_d[census_pd_d["Zipcode"].isin([
    "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
    "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
    "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
    "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
    "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
    "95841", "95842", "95843", "95864"])]


# Label year of 2017 to Zipcodes
census_sac_d["Zipcode"] = "2017-" + census_sac_d["Zipcode"].astype(str)

# Drop bad data
# (Removed 95652, 95680)
# (Removed 95615 to align with 2018)
census_sac_d = census_sac_d.dropna(how='any')
census_sac_d = census_sac_d.loc[(census_sac_d["Median Home Value"] > -666666666)]
census_sac_d = census_sac_d.loc[(census_sac_d["Median Household Income"] > -666666666)]
census_sac_d = census_sac_d.loc[(census_sac_d["Zipcode"] != "95615")]


# Visualize
print(len(census_sac_d))
census_sac_d
# Out:
# 52
#           Zipcode  Population  Poverty Count  Poverty Rate  \
# 31164  2017-95608     61365.0         9010.0         14.68
# 31165  2017-95610     45429.0         6215.0         13.68
# 31168  2017-95615      1015.0          211.0         20.79
# 31173  2017-95621     41893.0         5315.0         12.69
# 31175  2017-95624     65447.0         6281.0          9.60
# 31177  2017-95626      6030.0          629.0         10.43
# 31179  2017-95628     40882.0         4131.0         10.10
# 31181  2017-95630     75864.0         3485.0          4.59
# 31183  2017-95632     31523.0         4959.0         15.73
# 31189  2017-95638      2204.0           90.0          4.08
# 31190  2017-95639       309.0            0.0          0.00
# 31192  2017-95641      1657.0          302.0         18.23
# 31201  2017-95655      4091.0          827.0         20.22
# 31204  2017-95660     35397.0         9520.0         26.89
# 31206  2017-95662     31738.0         2925.0          9.22
# 31214  2017-95670     54348.0         7916.0         14.57
# 31216  2017-95673     15604.0         2680.0         17.18
# 31224  2017-95683      6173.0          286.0          4.63
# 31231  2017-95690      2346.0          189.0          8.06
# 31234  2017-95693      6408.0          468.0          7.30
# 31252  2017-95742     11119.0          698.0          6.28
# 31255  2017-95757     48242.0         3748.0          7.77
# 31256  2017-95758     63977.0         6803.0         10.63
# 31260  2017-95811      5874.0         1683.0         28.65
# 31261  2017-95814     11023.0         2416.0         21.92
# 31262  2017-95815     25606.0         9220.0         36.01
# 31263  2017-95816     17143.0         1966.0         11.47
# 31281                1042.0                  57296.0            27030.0
# 31282                 506.0                  87794.0            36834.0
# 31283                   0.0                 225000.0            86550.0
# 31284                1894.0                  41970.0            16744.0
# 31285                1016.0                  42133.0            22458.0
# 31286                1387.0                  47705.0            21179.0
# 31287                1401.0                  71041.0            25383.0
# 31288                 237.0                  96643.0            57039.0
#
#        Median Home Value
# 31164           354700.0
# 31165           276300.0
# 31168           334000.0
# 31173           221800.0
# 31175           350200.0
# 31177           290600.0
# 31179           377500.0
# 31181           456900.0
# 31183           290500.0
# 31189           461000.0
# 31190           354200.0
# 31192           212200.0
# 31201           308000.0
# 31204           162900.0
# 31206           330900.0
# 31214           274500.0
# 31216           223500.0
# 31224           442000.0
# 31231           449500.0
# 31234           519000.0
# 31252           368800.0
# 31255           392900.0
# 31256           312100.0
# 31260           481000.0
# 31261           378000.0
# 31262           177100.0
# 31263           504400.0
# 31264           287300.0
# 31265           492400.0
# 31266           471300.0
# 31267           206500.0
# 31268           293200.0
# 31269           266400.0
# 31270           194000.0
# 31271           152900.0
# 31272           251500.0
# 31273           254700.0
# 31274           216300.0
# 31275           201100.0
# 31276           340500.0
# 31277           519500.0
# 31278           375200.0
# 31279           205100.0
# 31280           228000.0
# 31281           286000.0
# 31282           348200.0
# 31283           625000.0
# 31284           169900.0
# 31285           214900.0
# 31286           197500.0
# 31287           275700.0
# 31288           531300.0

# %%
# Run Census Search to retrieve data on all zip codes (2018)
census_data_e = e.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
                          "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
census_pd_e = pd.DataFrame(census_data_e)

# Column Reordering
census_pd_e = census_pd_e.rename(columns={
    "B01003_001E": "Population", 
    "B17001_002E": "Poverty Count", 
    "B17012_002E": "Family Poverty Count",
    "B19013_001E": "Median Household Income", 
    "B19301_001E": "Per Capita Income", 
    "B25077_001E": "Median Home Value",
    "NAME": "Name", "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd_e["Poverty Rate"] = (100 * census_pd_e["Poverty Count"].astype(float) / census_pd_e["Population"].astype(float)).round(2)

# Final DataFrame
census_pd_e = census_pd_e[[
    "Zipcode", 
    "Population", 
    "Poverty Count", 
    "Poverty Rate",
    "Family Poverty Count", 
    "Median Household Income", 
    "Per Capita Income", 
    "Median Home Value"]]

# Filter Zipcode: limited to Sac County
census_sac_e = census_pd_e[census_pd_e["Zipcode"].isin([
    "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
    "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
    "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
    "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
    "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
    "95841", "95842", "95843", "95864"])]

# Label year of 2018 to Zipcodes
census_sac_e["Zipcode"] = "2018-" + census_sac_e["Zipcode"].astype(str)

# Drop bad data
# (Removed 95652, 95680)
census_sac_e = census_sac_e.dropna(how='any')
census_sac_e = census_sac_e.loc[(census_sac_e["Median Home Value"] > -666666666)]
census_sac_e = census_sac_e.loc[(census_sac_e["Median Household Income"] > -666666666)]

# Visualize
print(len(census_sac_e))
census_sac_e
# Out:
# 51
#           Zipcode  Population  Poverty Count  Poverty Rate  \
# 31135  2018-95608     61860.0         9799.0         15.84
# 31136  2018-95610     45995.0         5987.0         13.02
# 31144  2018-95621     41757.0         4450.0         10.66
# 31146  2018-95624     65742.0         6349.0          9.66
# 31148  2018-95626      6335.0          640.0         10.10
# 31150  2018-95628     41121.0         3866.0          9.40
# 31152  2018-95630     76973.0         3828.0          4.97
# 31154  2018-95632     31431.0         3851.0         12.25
# 31160  2018-95638      2121.0          171.0          8.06
# 31161  2018-95639       321.0            0.0          0.00
# 31163  2018-95641      1548.0          285.0         18.41
# 31172  2018-95655      4178.0          600.0         14.36
# 31175  2018-95660     36472.0         9456.0         25.93
# 31177  2018-95662     32006.0         2979.0          9.31
# 31185  2018-95670     54648.0         7186.0         13.15
# 31187  2018-95673     15753.0         2765.0         17.55
# 31195  2018-95683      6279.0          199.0          3.17
# 31202  2018-95690      2122.0          167.0          7.87
# 31205  2018-95693      6759.0          424.0          6.27
# 31223  2018-95742     11921.0          818.0          6.86
# 31226  2018-95757     49683.0         3539.0          7.12
# 31227  2018-95758     63894.0         6697.0         10.48
# 31231  2018-95811      6050.0         1547.0         25.57
# 31232  2018-95814     11340.0         2561.0         22.58
# 31233  2018-95815     25224.0         8716.0         34.55
# 31234  2018-95816     17217.0         1751.0         10.17
# 31235  2018-95817     13461.0         3084.0         22.91
# 31236  2018-95818     21732.0         3506.0         16.13
# 31237  2018-95819     19659.0         1185.0          6.03
# 31238  2018-95820     35477.0         8511.0         23.99
# 31239  2018-95821     35430.0         8526.0         24.06
# 31240  2018-95822     45323.0         7730.0         17.06
# 31241  2018-95823     79272.0        19229.0         24.26
# 31242  2018-95824     30296.0        10696.0         35.30
# 31243  2018-95825     35825.0        11710.0         32.69
# 31244  2018-95826     38256.0         7161.0         18.72
# 31245  2018-95827     21185.0         2976.0         14.05
# 31246  2018-95828     60270.0        12073.0         20.03
# 31247  2018-95829     28134.0         2804.0          9.97
# 31248  2018-95830       902.0          227.0         25.17
# 31249  2018-95831     42514.0         3580.0          8.42
# 31250  2018-95832     11518.0         2805.0         24.35
# 31251  2018-95833     41209.0         5986.0         14.53
# 31252  2018-95834     28229.0         4272.0         15.13
# 31253  2018-95835     40101.0         2351.0          5.86
# 31254  2018-95837       305.0           40.0         13.11
# 31255  2018-95838     39187.0         9989.0         25.49
# 31256  2018-95841     20586.0         3964.0         19.26
# 31257  2018-95842     32269.0         7050.0         21.85
# 31258  2018-95843     46709.0         5818.0         12.46
# 31259  2018-95864     23733.0         1720.0          7.25
#
#        Family Poverty Count  Median Household Income  Per Capita Income  \
# 31135                1800.0                  61437.0            38483.0
# 31136                1073.0                  58780.0            29122.0
# 31144                 755.0                  59693.0            29377.0
# 31146                1275.0                  91971.0            35090.0
# 31148                  79.0                  73355.0            28332.0
# 13504  2016-95608     60199.0         8680.0         14.42
# 13505  2016-95610     44711.0         6767.0         15.13
# 13508  2016-95615       970.0          197.0         20.31
# 13513  2016-95621     41908.0         5809.0         13.86
# 13515  2016-95624     64429.0         6571.0         10.20
# ...           ...         ...            ...           ...
# 31255  2018-95838     39187.0         9989.0         25.49
# 31256  2018-95841     20586.0         3964.0         19.26
# 31257  2018-95842     32269.0         7050.0         21.85
# 31258  2018-95843     46709.0         5818.0         12.46
# 31259  2018-95864     23733.0         1720.0          7.25
#
#        Family Poverty Count  Median Household Income  Per Capita Income  \
# 13504                1392.0                  56891.0            36796.0
# 13505                1075.0                  51271.0            25814.0
# 13508                   0.0                  66080.0            26284.0
# 13513                 986.0                  52462.0            25123.0
# 13515                1310.0                  84854.0            32386.0
# ...                     ...                      ...                ...
# 31255                1847.0                  44849.0            17299.0
# 31256                 885.0                  47215.0            25167.0
# 31257                1386.0                  50412.0            22419.0
# 31258                1248.0                  78102.0            27488.0
# 31259                 257.0                 101446.0            60946.0
#
#        Median Home Value
# 13504           331500.0
# 13505           248000.0
# 13508           309600.0
# 13513           196200.0
# 13515           318900.0
# ...                  ...
# 31255           201900.0
# 31256           233300.0
# 31257           222300.0
# 31258           299900.0
# 31259           562600.0
#
# [155 rows x 8 columns]

# %%
census_sac_cde.to_csv("census_sac_cde.csv", encoding="utf-8", index=False)

# %%
# # Run Census Search to retrieve data on all zip codes (2019)
# census_data_f = f.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B17001_002E",
#                           "B17012_002E", "B01003_001E", "B25077_001E"), {'for': 'zip code tabulation area:*'})

# # Convert to DataFrame
# census_pd_f = pd.DataFrame(census_data_f)

# # Column Reordering
# census_pd_f = census_pd_f.rename(columns={
#     "B01003_001E": "Population", 
#     "B17001_002E": "Poverty Count", 
#     "B17012_002E": "Family Poverty Count",
#     "B19013_001E": "Median Household Income", 
#     "B19301_001E": "Per Capita Income", 
#     "B25077_001E": "Median Home Value",
#     "NAME": "Name", "zip code tabulation area": "Zipcode"})

# # Add in Poverty Rate (Poverty Count / Population)
# census_pd_f["Poverty Rate"] = (100 * census_pd_f["Poverty Count"].astype(float) / census_pd_f["Population"].astype(float)).round(2)

# # Final DataFrame
# census_pd_f = census_pd_f[[
#     "Zipcode", 
#     "Population", 
#     "Poverty Count", 
#     "Poverty Rate",
#     "Family Poverty Count", 
#     "Median Household Income", 
#     "Per Capita Income", 
#     "Median Home Value"]]

# # Filter Zipcode: limited to Sac County
# census_sac_f = census_pd_f[census_pd_f["Zipcode"].isin([
#     "95608", "95610", "95615", "95621", "95624", "95626", "95628", "95630", "95632", "95638", 
#     "95639", "95641", "95652", "95655", "95660", "95662", "95670", "95673", "95680", "95683",
#     "95690", "95693", "95742", "95757", "95758", "95811", "95814", "95815", "95816", "95817",
#     "95818", "95819", "95820", "95821", "95822", "95823", "95824", "95825", "95826", "95827",
#     "95828", "95829", "95830", "95831", "95832", "95833", "95834", "95835", "95837", "95838", 
#     "95841", "95842", "95843", "95864"])]


# # Visualize
# print(len(census_sac_f))
# census_sac_f.head()
