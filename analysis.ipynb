# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from scipy.stats import linregress
import requests
import json
from pprint import pprint
import gmaps
from config import g_key

# %%
# Read in the Crimes
clean_crime_df = pd.read_csv("./Resources/Crime_clean.csv")
clean_personal_crime_df = pd.read_csv("./Resources/Crime_Persons_clean.csv")
clean_crime_df.head()
# Out:
#               X             Y     FID ActivityNumber       District  \
# 0  1.517236e-04 -2.607703e-06       2   ]\="-0092335  North Central
# 1  6.756477e+06  1.974923e+06       3  03/30-0055028           East
# 2  6.754609e+06  1.968828e+06  226871   2014-0000030           East
# 3  6.747809e+06  1.969023e+06  226872   2014-0000031      Elk Grove
# 4  6.728042e+06  1.985577e+06  226874   2014-0000033  North Central
#
#       Neighborhood   OccurenceStartDate     OccurenceEndDate  \
# 0  Carmichael Park  2018/03/19 21:30:00  2018/03/19 21:59:59
# 1  Cordova Meadows  2015/03/06 01:11:00  2015/03/06 01:11:00
# 2  Lincoln Village  2014/01/01 00:14:59  2014/01/01 00:14:59
# 3      Butterfield  2014/01/01 00:27:00  2014/01/01 00:27:00
# 4         Bellview  2014/01/01 00:24:59  2014/01/01 00:27:00
#
#             ReportDate     OccurenceLocation   OccurenceCity  ZipCode  \
# 0  2018/03/20 17:00:00  5100 Block of Janell      Carmichael    95608
# 1  2015/03/06 00:00:00  10000 Block of Terra  Rancho Cordova    95670
# 2  2014/01/01 00:42:00  3300 Block of Explor      Sacramento    95827
# 3  2014/01/01 00:30:00  9300 Block of Mira D      Sacramento    95827
# 4  2014/01/01 00:48:00  2600 Block of Darwin      Sacramento    95821
#
#                                  PrimaryViolation             DateTime  Year  \
# 0              PC 273.5 Inflict Crpl Inj Sp/Cohab  2018-03-19 21:30:00  2018
# 1        PC 594(B)(2)(A) Vandalism Less Than $400  2015-03-06 01:11:00  2015
# 2  PC 246 Shoot At Inhabited Dwelling/Vehicle/Etc  2014-01-01 00:14:59  2014
# 3                                 PC 459 Burglary  2014-01-01 00:27:00  2014
# 4                             PC 594(A) Vandalism  2014-01-01 00:24:59  2014
#
#       PC
# 0  273.5
# 1  594.0
# 2  246.0
# 3  459.0
# 4  594.0

# %%
# Create a new data frame with just the zip codes and the sum of the pc's
clean_crime_min_df = pd.DataFrame()
clean_crime_min_df["PC"] = clean_crime_df["PC"]
clean_crime_min_df["Year"] = clean_crime_df["Year"]
clean_crime_min_df["ZipCode"] = clean_crime_df["ZipCode"]
clean_crime_min_df.head()
clean_crime_sum_group = clean_crime_min_df.groupby(["Year", "ZipCode"]).count()
clean_crime_sum_group
# Out:
#                 PC
# Year ZipCode
# 2014 92345       1
#      94043       1
#      94571      16
#      95501       1
#      95608    1745
# ...            ...
# 2018 95843     925
#      95864     520
#      95949       1
#      95961       1
#      95991       1
#
# [351 rows x 1 columns]

# %%
# Create a new data frame with just the zip codes and the sum of the pc's
clean_crime_personal_min_df = pd.DataFrame()
clean_crime_personal_min_df["PC"] = clean_personal_crime_df["PC"]
clean_crime_personal_min_df["Year"] = clean_personal_crime_df["Year"]
clean_crime_personal_min_df["ZipCode"] = clean_personal_crime_df["ZipCode"]
clean_crime_personal_min_df.head()
clean_crime_personal_sum_group = clean_crime_personal_min_df.groupby(["Year", "ZipCode"]).count()
clean_crime_personal_sum_group
# Out:
#                PC
# Year ZipCode
# 2014 92345      1
#      94043      1
#      94571      2
#      95501      1
#      95608    229
# ...           ...
# 2018 95842    311
#      95843    236
#      95864     83
#      95961      1
#      95991      1
#
# [278 rows x 1 columns]

# %%
# Read in the Census data
census_df = pd.read_csv("./Resources/census_output_final.csv")
census_df.head()
# Out:
#    Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0  2014    95608     60729.0         8301.0         13.67
# 1  2014    95610     43572.0         7174.0         16.46
# 2  2014    95621     41474.0         5842.0         14.09
# 3  2014    95624     63131.0         6848.0         10.85
# 4  2014    95626      6335.0          792.0         12.50
#
#    Family Poverty Count  Median Household Income  Per Capita Income  \
# 0                1476.0                  55256.0            34606.0
# 1                1136.0                  50536.0            25288.0
# 2                1069.0                  51827.0            24379.0
# 3                1266.0                  80233.0            29752.0
# 4                 182.0                  60579.0            22576.0
#
#    Median Home Value
# 0           304200.0
# 1           217100.0
# 2           173700.0
# 3           270400.0
# 4           193900.0

# %%
# Merge the crime and the census data
merged_all_df = pd.merge(census_df, clean_crime_sum_group, how="left", left_on=["Year", "ZipCode"], right_on=["Year", "ZipCode"])
merged_all_df["Crime Rate"] = (100 * merged_all_df["PC"]/merged_all_df["Population"]).round(2)
merged_all_df.fillna(0, inplace=True)
merged_all_df.head()
# Out:
#    Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0  2014    95608     60729.0         8301.0         13.67
# 1  2014    95610     43572.0         7174.0         16.46
# 2  2014    95621     41474.0         5842.0         14.09
# 3  2014    95624     63131.0         6848.0         10.85
# 4  2014    95626      6335.0          792.0         12.50
#
#    Family Poverty Count  Median Household Income  Per Capita Income  \
# 0                1476.0                  55256.0            34606.0
# 1                1136.0                  50536.0            25288.0
# 2                1069.0                  51827.0            24379.0
# 3                1266.0                  80233.0            29752.0
# 4                 182.0                  60579.0            22576.0
#
#    Median Home Value      PC  Crime Rate
# 0           304200.0  1745.0        2.87
# 1           217100.0     8.0        0.02
# 2           173700.0    38.0        0.09
# 3           270400.0     6.0        0.01
# 4           193900.0    70.0        1.10

# %%
# Merge the crime and the census data
merged_personal_df = pd.merge(census_df, clean_crime_personal_sum_group, how="left", left_on=["Year", "ZipCode"], right_on=["Year", "ZipCode"])
merged_personal_df["Crime Rate"] = (100 * merged_personal_df["PC"]/merged_personal_df["Population"]).round(2)
merged_personal_df.fillna(0, inplace=True)
merged_personal_df
# Out:
#      Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0    2014    95608     60729.0         8301.0         13.67
# 1    2014    95610     43572.0         7174.0         16.46
# 2    2014    95621     41474.0         5842.0         14.09
# 3    2014    95624     63131.0         6848.0         10.85
# 4    2014    95626      6335.0          792.0         12.50
# ..    ...      ...         ...            ...           ...
# 240  2018    95838     39187.0         9989.0         25.49
# 241  2018    95841     20586.0         3964.0         19.26
# 242  2018    95842     32269.0         7050.0         21.85
# 243  2018    95843     46709.0         5818.0         12.46
# 244  2018    95864     23733.0         1720.0          7.25
#
#      Family Poverty Count  Median Household Income  Per Capita Income  \
# 0                  1476.0                  55256.0            34606.0
# 1                  1136.0                  50536.0            25288.0
# 2                  1069.0                  51827.0            24379.0
# 3                  1266.0                  80233.0            29752.0
# 4                   182.0                  60579.0            22576.0
# ..                    ...                      ...                ...
# 240                1847.0                  44849.0            17299.0
# 241                 885.0                  47215.0            25167.0
# 242                1386.0                  50412.0            22419.0
# 243                1248.0                  78102.0            27488.0
# 244                 257.0                 101446.0            60946.0
#
#      Median Home Value     PC  Crime Rate
# 0             304200.0  229.0        0.38
# 1             217100.0    2.0        0.00
# 2             173700.0   10.0        0.02
# 3             270400.0    0.0        0.00
# 4             193900.0    5.0        0.08
# ..                 ...    ...         ...
# 240           201900.0    2.0        0.01
# 241           233300.0  234.0        1.14
# 242           222300.0  311.0        0.96
# 243           299900.0  236.0        0.51
# 244           562600.0   83.0        0.35
#
# [245 rows x 11 columns]

# %%
# Write out the Data Frames
merged_all_df.to_csv("./Resources/merged_all_df.csv")
merged_personal_df.to_csv("./Resources/merged_personal_df.csv")

# %%
gmaps.configure(api_key=g_key)
# zipcode = "95608"
# base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={zipcode}&key={g_key}"
# # print(base_url)
# response = requests.get(base_url)
# data = response.json()
# pprint(data['results'])

# %%
merged_all_df["Lat"] = 0
merged_all_df["Lng"] = 0
# Iterate over the rows in the dataframe
for index, row in merged_all_df.iterrows():
    zipcode = int(row["ZipCode"])
    print(f"Gathering Lat/Lng for Zip Code {zipcode} Index = {index}")
    base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={zipcode}&key={g_key}"
    response = requests.get(base_url)
    data = response.json()
    results = data['results']
    try:
        lat = results[0]["geometry"]["location"]["lat"]
        lng = results[0]["geometry"]["location"]["lng"]
        merged_all_df.loc[index, "Lat"] = lat
        merged_all_df.loc[index, "Lng"] = lng
    except (KeyError, IndexError):
        print(f"Error with Zip Code {zipcode} Index = {index}")
        merged_all_df.loc[index, "Lat"] = 0
        merged_all_df.loc[index, "Lng"] = 0

merged_all_df.head()
# Out:
# Gathering Lat/Lon for Zip Code 95608 Index = 0
# Gathering Lat/Lon for Zip Code 95610 Index = 1
# Gathering Lat/Lon for Zip Code 95621 Index = 2
# Gathering Lat/Lon for Zip Code 95624 Index = 3
# Gathering Lat/Lon for Zip Code 95626 Index = 4
# Gathering Lat/Lon for Zip Code 95628 Index = 5
# Gathering Lat/Lon for Zip Code 95630 Index = 6
# Gathering Lat/Lon for Zip Code 95632 Index = 7
# Gathering Lat/Lon for Zip Code 95638 Index = 8
# Gathering Lat/Lon for Zip Code 95639 Index = 9
# Gathering Lat/Lon for Zip Code 95641 Index = 10
# Gathering Lat/Lon for Zip Code 95655 Index = 11
# Gathering Lat/Lon for Zip Code 95660 Index = 12
# Gathering Lat/Lon for Zip Code 95662 Index = 13
# Gathering Lat/Lon for Zip Code 95670 Index = 14
# Gathering Lat/Lon for Zip Code 95673 Index = 15
# Gathering Lat/Lon for Zip Code 95683 Index = 16
# Gathering Lat/Lon for Zip Code 95690 Index = 17
# Gathering Lat/Lon for Zip Code 95693 Index = 18
# Gathering Lat/Lon for Zip Code 95742 Index = 19
# Gathering Lat/Lon for Zip Code 95758 Index = 20
# Gathering Lat/Lon for Zip Code 95814 Index = 21
# Gathering Lat/Lon for Zip Code 95815 Index = 22
# Gathering Lat/Lon for Zip Code 95816 Index = 23
# Gathering Lat/Lon for Zip Code 95817 Index = 24
# Gathering Lat/Lon for Zip Code 95818 Index = 25
# Gathering Lat/Lon for Zip Code 95819 Index = 26
# Gathering Lat/Lon for Zip Code 95820 Index = 27
# Gathering Lat/Lon for Zip Code 95821 Index = 28
# Gathering Lat/Lon for Zip Code 95822 Index = 29
# Gathering Lat/Lon for Zip Code 95823 Index = 30
# Gathering Lat/Lon for Zip Code 95824 Index = 31
# Gathering Lat/Lon for Zip Code 95825 Index = 32
# Gathering Lat/Lon for Zip Code 95826 Index = 33
# Gathering Lat/Lon for Zip Code 95827 Index = 34
# Gathering Lat/Lon for Zip Code 95828 Index = 35
# Gathering Lat/Lon for Zip Code 95829 Index = 36
# Gathering Lat/Lon for Zip Code 95830 Index = 37
# Gathering Lat/Lon for Zip Code 95831 Index = 38
# Gathering Lat/Lon for Zip Code 95832 Index = 39
# Gathering Lat/Lon for Zip Code 95833 Index = 40
# Gathering Lat/Lon for Zip Code 95834 Index = 41
# Gathering Lat/Lon for Zip Code 95835 Index = 42
# Gathering Lat/Lon for Zip Code 95837 Index = 43
# Gathering Lat/Lon for Zip Code 95838 Index = 44
# Gathering Lat/Lon for Zip Code 95841 Index = 45
# Gathering Lat/Lon for Zip Code 95842 Index = 46
# Gathering Lat/Lon for Zip Code 95843 Index = 47
# Gathering Lat/Lon for Zip Code 95864 Index = 48
# Gathering Lat/Lon for Zip Code 95608 Index = 49
# Gathering Lat/Lon for Zip Code 95610 Index = 50
# Gathering Lat/Lon for Zip Code 95621 Index = 51
# Gathering Lat/Lon for Zip Code 95624 Index = 52
# Gathering Lat/Lon for Zip Code 95626 Index = 53
# Gathering Lat/Lon for Zip Code 95628 Index = 54
# Gathering Lat/Lon for Zip Code 95630 Index = 55
# Gathering Lat/Lon for Zip Code 95632 Index = 56
# Gathering Lat/Lon for Zip Code 95638 Index = 57
# Gathering Lat/Lon for Zip Code 95639 Index = 58
# Gathering Lat/Lon for Zip Code 95641 Index = 59
# Gathering Lat/Lon for Zip Code 95655 Index = 60
# Gathering Lat/Lon for Zip Code 95660 Index = 61
# Gathering Lat/Lon for Zip Code 95662 Index = 62
# Gathering Lat/Lon for Zip Code 95670 Index = 63
# Gathering Lat/Lon for Zip Code 95673 Index = 64
# Gathering Lat/Lon for Zip Code 95683 Index = 65
# Gathering Lat/Lon for Zip Code 95690 Index = 66
# Gathering Lat/Lon for Zip Code 95693 Index = 67
# Gathering Lat/Lon for Zip Code 95742 Index = 68
# Gathering Lat/Lon for Zip Code 95758 Index = 69
# Gathering Lat/Lon for Zip Code 95814 Index = 70
# Gathering Lat/Lon for Zip Code 95815 Index = 71
# Gathering Lat/Lon for Zip Code 95816 Index = 72
# Gathering Lat/Lon for Zip Code 95817 Index = 73
# Gathering Lat/Lon for Zip Code 95818 Index = 74
# Gathering Lat/Lon for Zip Code 95819 Index = 75
# Gathering Lat/Lon for Zip Code 95820 Index = 76
# Gathering Lat/Lon for Zip Code 95821 Index = 77
# Gathering Lat/Lon for Zip Code 95822 Index = 78
# Gathering Lat/Lon for Zip Code 95823 Index = 79
# Gathering Lat/Lon for Zip Code 95824 Index = 80
# Gathering Lat/Lon for Zip Code 95825 Index = 81
# Gathering Lat/Lon for Zip Code 95826 Index = 82
# Gathering Lat/Lon for Zip Code 95827 Index = 83
# Gathering Lat/Lon for Zip Code 95828 Index = 84
# Gathering Lat/Lon for Zip Code 95829 Index = 85
# Gathering Lat/Lon for Zip Code 95830 Index = 86
# Gathering Lat/Lon for Zip Code 95831 Index = 87
# Gathering Lat/Lon for Zip Code 95832 Index = 88
# Gathering Lat/Lon for Zip Code 95833 Index = 89
# Gathering Lat/Lon for Zip Code 95834 Index = 90
# Gathering Lat/Lon for Zip Code 95835 Index = 91
# Gathering Lat/Lon for Zip Code 95837 Index = 92
# Gathering Lat/Lon for Zip Code 95838 Index = 93
# Gathering Lat/Lon for Zip Code 95841 Index = 94
# Gathering Lat/Lon for Zip Code 95842 Index = 95
# Gathering Lat/Lon for Zip Code 95843 Index = 96
# Gathering Lat/Lon for Zip Code 95864 Index = 97
# Gathering Lat/Lon for Zip Code 95608 Index = 98
# Gathering Lat/Lon for Zip Code 95610 Index = 99
# Gathering Lat/Lon for Zip Code 95621 Index = 100
# Gathering Lat/Lon for Zip Code 95624 Index = 101
# Gathering Lat/Lon for Zip Code 95626 Index = 102
# Gathering Lat/Lon for Zip Code 95628 Index = 103
# Gathering Lat/Lon for Zip Code 95630 Index = 104
# Gathering Lat/Lon for Zip Code 95632 Index = 105
# Gathering Lat/Lon for Zip Code 95638 Index = 106
# Gathering Lat/Lon for Zip Code 95639 Index = 107
# Gathering Lat/Lon for Zip Code 95641 Index = 108
# Gathering Lat/Lon for Zip Code 95655 Index = 109
# Gathering Lat/Lon for Zip Code 95660 Index = 110
# Gathering Lat/Lon for Zip Code 95662 Index = 111
# Gathering Lat/Lon for Zip Code 95670 Index = 112
# Gathering Lat/Lon for Zip Code 95673 Index = 113
# Gathering Lat/Lon for Zip Code 95683 Index = 114
# Gathering Lat/Lon for Zip Code 95690 Index = 115
# Gathering Lat/Lon for Zip Code 95693 Index = 116
# Gathering Lat/Lon for Zip Code 95742 Index = 117
# Gathering Lat/Lon for Zip Code 95758 Index = 118
# Gathering Lat/Lon for Zip Code 95814 Index = 119
# Gathering Lat/Lon for Zip Code 95815 Index = 120
# Gathering Lat/Lon for Zip Code 95816 Index = 121
# Gathering Lat/Lon for Zip Code 95817 Index = 122
# Gathering Lat/Lon for Zip Code 95818 Index = 123
# Gathering Lat/Lon for Zip Code 95819 Index = 124
# Gathering Lat/Lon for Zip Code 95820 Index = 125
# Gathering Lat/Lon for Zip Code 95821 Index = 126
# Gathering Lat/Lon for Zip Code 95822 Index = 127
# Gathering Lat/Lon for Zip Code 95823 Index = 128
# Gathering Lat/Lon for Zip Code 95824 Index = 129
# Gathering Lat/Lon for Zip Code 95825 Index = 130
# Gathering Lat/Lon for Zip Code 95826 Index = 131
# Gathering Lat/Lon for Zip Code 95827 Index = 132
# Gathering Lat/Lon for Zip Code 95828 Index = 133
# Gathering Lat/Lon for Zip Code 95829 Index = 134
# Gathering Lat/Lon for Zip Code 95830 Index = 135
# Gathering Lat/Lon for Zip Code 95831 Index = 136
# Gathering Lat/Lon for Zip Code 95832 Index = 137
# Gathering Lat/Lon for Zip Code 95833 Index = 138
# Gathering Lat/Lon for Zip Code 95834 Index = 139
# Gathering Lat/Lon for Zip Code 95835 Index = 140
# Gathering Lat/Lon for Zip Code 95837 Index = 141
# Gathering Lat/Lon for Zip Code 95838 Index = 142
# Gathering Lat/Lon for Zip Code 95841 Index = 143
# Gathering Lat/Lon for Zip Code 95842 Index = 144
# Gathering Lat/Lon for Zip Code 95843 Index = 145
# Gathering Lat/Lon for Zip Code 95864 Index = 146
# Gathering Lat/Lon for Zip Code 95608 Index = 147
# Gathering Lat/Lon for Zip Code 95610 Index = 148
# Gathering Lat/Lon for Zip Code 95621 Index = 149
# Gathering Lat/Lon for Zip Code 95624 Index = 150
# Gathering Lat/Lon for Zip Code 95626 Index = 151
# Gathering Lat/Lon for Zip Code 95628 Index = 152
# Gathering Lat/Lon for Zip Code 95630 Index = 153
# Gathering Lat/Lon for Zip Code 95632 Index = 154
# Gathering Lat/Lon for Zip Code 95638 Index = 155
# Gathering Lat/Lon for Zip Code 95639 Index = 156
# Gathering Lat/Lon for Zip Code 95641 Index = 157
# Gathering Lat/Lon for Zip Code 95655 Index = 158
# Gathering Lat/Lon for Zip Code 95660 Index = 159
# Gathering Lat/Lon for Zip Code 95662 Index = 160
# Gathering Lat/Lon for Zip Code 95670 Index = 161
# Gathering Lat/Lon for Zip Code 95673 Index = 162
# Gathering Lat/Lon for Zip Code 95683 Index = 163
# Gathering Lat/Lon for Zip Code 95690 Index = 164
# Gathering Lat/Lon for Zip Code 95693 Index = 165
# Gathering Lat/Lon for Zip Code 95742 Index = 166
# Gathering Lat/Lon for Zip Code 95758 Index = 167
# Gathering Lat/Lon for Zip Code 95814 Index = 168
# Gathering Lat/Lon for Zip Code 95815 Index = 169
# Gathering Lat/Lon for Zip Code 95816 Index = 170
# Gathering Lat/Lon for Zip Code 95817 Index = 171
# Gathering Lat/Lon for Zip Code 95818 Index = 172
# Gathering Lat/Lon for Zip Code 95819 Index = 173
# Gathering Lat/Lon for Zip Code 95820 Index = 174
# Gathering Lat/Lon for Zip Code 95821 Index = 175
# Gathering Lat/Lon for Zip Code 95822 Index = 176
# Gathering Lat/Lon for Zip Code 95823 Index = 177
# Gathering Lat/Lon for Zip Code 95824 Index = 178
# Gathering Lat/Lon for Zip Code 95825 Index = 179
# Gathering Lat/Lon for Zip Code 95826 Index = 180
# Gathering Lat/Lon for Zip Code 95827 Index = 181
# Gathering Lat/Lon for Zip Code 95828 Index = 182
# Gathering Lat/Lon for Zip Code 95829 Index = 183
# Gathering Lat/Lon for Zip Code 95830 Index = 184
# Gathering Lat/Lon for Zip Code 95831 Index = 185
# Gathering Lat/Lon for Zip Code 95832 Index = 186
# Gathering Lat/Lon for Zip Code 95833 Index = 187
# Gathering Lat/Lon for Zip Code 95834 Index = 188
# Gathering Lat/Lon for Zip Code 95835 Index = 189
# Gathering Lat/Lon for Zip Code 95837 Index = 190
# Gathering Lat/Lon for Zip Code 95838 Index = 191
# Gathering Lat/Lon for Zip Code 95841 Index = 192
# Gathering Lat/Lon for Zip Code 95842 Index = 193
# Gathering Lat/Lon for Zip Code 95843 Index = 194
# Gathering Lat/Lon for Zip Code 95864 Index = 195
# Gathering Lat/Lon for Zip Code 95608 Index = 196
# Gathering Lat/Lon for Zip Code 95610 Index = 197
# Gathering Lat/Lon for Zip Code 95621 Index = 198
# Gathering Lat/Lon for Zip Code 95624 Index = 199
# Gathering Lat/Lon for Zip Code 95626 Index = 200
# Gathering Lat/Lon for Zip Code 95628 Index = 201
# Gathering Lat/Lon for Zip Code 95630 Index = 202
# Gathering Lat/Lon for Zip Code 95632 Index = 203
# Gathering Lat/Lon for Zip Code 95638 Index = 204
# Gathering Lat/Lon for Zip Code 95639 Index = 205
# Gathering Lat/Lon for Zip Code 95641 Index = 206
# Gathering Lat/Lon for Zip Code 95655 Index = 207
# Gathering Lat/Lon for Zip Code 95660 Index = 208
# Gathering Lat/Lon for Zip Code 95662 Index = 209
# Gathering Lat/Lon for Zip Code 95670 Index = 210
# Gathering Lat/Lon for Zip Code 95673 Index = 211
# Gathering Lat/Lon for Zip Code 95683 Index = 212
# Gathering Lat/Lon for Zip Code 95690 Index = 213
# Gathering Lat/Lon for Zip Code 95693 Index = 214
# Gathering Lat/Lon for Zip Code 95742 Index = 215
# Gathering Lat/Lon for Zip Code 95758 Index = 216
# Gathering Lat/Lon for Zip Code 95814 Index = 217
# Gathering Lat/Lon for Zip Code 95815 Index = 218
# Gathering Lat/Lon for Zip Code 95816 Index = 219
# Gathering Lat/Lon for Zip Code 95817 Index = 220
# Gathering Lat/Lon for Zip Code 95818 Index = 221
# Gathering Lat/Lon for Zip Code 95819 Index = 222
# Gathering Lat/Lon for Zip Code 95820 Index = 223
# Gathering Lat/Lon for Zip Code 95821 Index = 224
# Gathering Lat/Lon for Zip Code 95822 Index = 225
# Gathering Lat/Lon for Zip Code 95823 Index = 226
# Gathering Lat/Lon for Zip Code 95824 Index = 227
# Gathering Lat/Lon for Zip Code 95825 Index = 228
# Gathering Lat/Lon for Zip Code 95826 Index = 229
# Gathering Lat/Lon for Zip Code 95827 Index = 230
# Gathering Lat/Lon for Zip Code 95828 Index = 231
# Gathering Lat/Lon for Zip Code 95829 Index = 232
# Gathering Lat/Lon for Zip Code 95830 Index = 233
# Gathering Lat/Lon for Zip Code 95831 Index = 234
# Gathering Lat/Lon for Zip Code 95832 Index = 235
# Gathering Lat/Lon for Zip Code 95833 Index = 236
# Gathering Lat/Lon for Zip Code 95834 Index = 237
# Gathering Lat/Lon for Zip Code 95835 Index = 238
# Gathering Lat/Lon for Zip Code 95837 Index = 239
# Gathering Lat/Lon for Zip Code 95838 Index = 240
# Gathering Lat/Lon for Zip Code 95841 Index = 241
# Gathering Lat/Lon for Zip Code 95842 Index = 242
# Gathering Lat/Lon for Zip Code 95843 Index = 243
# Gathering Lat/Lon for Zip Code 95864 Index = 244
#    Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0  2014    95608     60729.0         8301.0         13.67
# 1  2014    95610     43572.0         7174.0         16.46
# 2  2014    95621     41474.0         5842.0         14.09
# 3  2014    95624     63131.0         6848.0         10.85
# 4  2014    95626      6335.0          792.0         12.50
#
#    Family Poverty Count  Median Household Income  Per Capita Income  \
# 0                1476.0                  55256.0            34606.0
# 1                1136.0                  50536.0            25288.0
# 2                1069.0                  51827.0            24379.0
# 3                1266.0                  80233.0            29752.0
# 4                 182.0                  60579.0            22576.0
#
#    Median Home Value      PC  Crime Rate        Lat         Lng
# 0           304200.0  1745.0        2.87  38.627279 -121.319849
# 1           217100.0     8.0        0.02  38.697745 -121.274081
# 2           173700.0    38.0        0.09  38.694001 -121.302688
# 3           270400.0     6.0        0.01  38.424402 -121.331288
# 4           193900.0    70.0        1.10  38.719089 -121.457045

# %%
merged_personal_df["Lat"] = 0
merged_personal_df["Lng"] = 0
# Iterate over the rows in the dataframe
for index, row in merged_personal_df.iterrows():
    zipcode = int(row["ZipCode"])
    print(f"Gathering Lat/Lng for Zip Code {zipcode} Index = {index}")
    base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={zipcode}&key={g_key}"
    response = requests.get(base_url)
    data = response.json()
    results = data['results']
    try:
        lat = results[0]["geometry"]["location"]["lat"]
        lng = results[0]["geometry"]["location"]["lng"]
        merged_personal_df.loc[index, "Lat"] = lat
        merged_personal_df.loc[index, "Lng"] = lng
    except (KeyError, IndexError):
        print(f"Error with Zip Code {zipcode} Index = {index}")
        merged_personal_df.loc[index, "Lat"] = 0
        merged_personal_df.loc[index, "Lng"] = 0

merged_personal_df.head()
# Out:
# Gathering Lat/Lng for Zip Code 95608 Index = 0
# Gathering Lat/Lng for Zip Code 95610 Index = 1
# Gathering Lat/Lng for Zip Code 95621 Index = 2
# Gathering Lat/Lng for Zip Code 95624 Index = 3
# Gathering Lat/Lng for Zip Code 95626 Index = 4
# Gathering Lat/Lng for Zip Code 95628 Index = 5
# Gathering Lat/Lng for Zip Code 95630 Index = 6
# Gathering Lat/Lng for Zip Code 95632 Index = 7
# Gathering Lat/Lng for Zip Code 95638 Index = 8
# Gathering Lat/Lng for Zip Code 95639 Index = 9
# Gathering Lat/Lng for Zip Code 95641 Index = 10
# Gathering Lat/Lng for Zip Code 95655 Index = 11
# Gathering Lat/Lng for Zip Code 95660 Index = 12
# Gathering Lat/Lng for Zip Code 95662 Index = 13
# Gathering Lat/Lng for Zip Code 95670 Index = 14
# Gathering Lat/Lng for Zip Code 95673 Index = 15
# Gathering Lat/Lng for Zip Code 95683 Index = 16
# Gathering Lat/Lng for Zip Code 95690 Index = 17
# Gathering Lat/Lng for Zip Code 95693 Index = 18
# Gathering Lat/Lng for Zip Code 95742 Index = 19
# Gathering Lat/Lng for Zip Code 95758 Index = 20
# Gathering Lat/Lng for Zip Code 95814 Index = 21
# Gathering Lat/Lng for Zip Code 95815 Index = 22
# Gathering Lat/Lng for Zip Code 95816 Index = 23
# Gathering Lat/Lng for Zip Code 95817 Index = 24
# Gathering Lat/Lng for Zip Code 95818 Index = 25
# Gathering Lat/Lng for Zip Code 95819 Index = 26
# Gathering Lat/Lng for Zip Code 95820 Index = 27
# Gathering Lat/Lng for Zip Code 95821 Index = 28
# Gathering Lat/Lng for Zip Code 95822 Index = 29
# Gathering Lat/Lng for Zip Code 95823 Index = 30
# Gathering Lat/Lng for Zip Code 95824 Index = 31
# Gathering Lat/Lng for Zip Code 95825 Index = 32
# Gathering Lat/Lng for Zip Code 95826 Index = 33
# Gathering Lat/Lng for Zip Code 95827 Index = 34
# Gathering Lat/Lng for Zip Code 95828 Index = 35
# Gathering Lat/Lng for Zip Code 95829 Index = 36
# Gathering Lat/Lng for Zip Code 95830 Index = 37
# Gathering Lat/Lng for Zip Code 95831 Index = 38
# Gathering Lat/Lng for Zip Code 95832 Index = 39
# Gathering Lat/Lng for Zip Code 95833 Index = 40
# Gathering Lat/Lng for Zip Code 95834 Index = 41
# Gathering Lat/Lng for Zip Code 95835 Index = 42
# Gathering Lat/Lng for Zip Code 95837 Index = 43
# Gathering Lat/Lng for Zip Code 95838 Index = 44
# Gathering Lat/Lng for Zip Code 95841 Index = 45
# Gathering Lat/Lng for Zip Code 95842 Index = 46
# Gathering Lat/Lng for Zip Code 95843 Index = 47
# Gathering Lat/Lng for Zip Code 95864 Index = 48
# Gathering Lat/Lng for Zip Code 95608 Index = 49
# Gathering Lat/Lng for Zip Code 95610 Index = 50
# Gathering Lat/Lng for Zip Code 95621 Index = 51
# Gathering Lat/Lng for Zip Code 95624 Index = 52
# Gathering Lat/Lng for Zip Code 95626 Index = 53
# Gathering Lat/Lng for Zip Code 95628 Index = 54
# Gathering Lat/Lng for Zip Code 95630 Index = 55
# Gathering Lat/Lng for Zip Code 95632 Index = 56
# Gathering Lat/Lng for Zip Code 95638 Index = 57
# Gathering Lat/Lng for Zip Code 95639 Index = 58
# Gathering Lat/Lng for Zip Code 95641 Index = 59
# Gathering Lat/Lng for Zip Code 95655 Index = 60
# Gathering Lat/Lng for Zip Code 95660 Index = 61
# Gathering Lat/Lng for Zip Code 95662 Index = 62
# Gathering Lat/Lng for Zip Code 95670 Index = 63
# Gathering Lat/Lng for Zip Code 95673 Index = 64
# Gathering Lat/Lng for Zip Code 95683 Index = 65
# Gathering Lat/Lng for Zip Code 95690 Index = 66
# Gathering Lat/Lng for Zip Code 95693 Index = 67
# Gathering Lat/Lng for Zip Code 95742 Index = 68
# Gathering Lat/Lng for Zip Code 95758 Index = 69
# Gathering Lat/Lng for Zip Code 95814 Index = 70
# Gathering Lat/Lng for Zip Code 95815 Index = 71
# Gathering Lat/Lng for Zip Code 95816 Index = 72
# Gathering Lat/Lng for Zip Code 95817 Index = 73
# Gathering Lat/Lng for Zip Code 95818 Index = 74
# Gathering Lat/Lng for Zip Code 95819 Index = 75
# Gathering Lat/Lng for Zip Code 95820 Index = 76
# Gathering Lat/Lng for Zip Code 95821 Index = 77
# Gathering Lat/Lng for Zip Code 95822 Index = 78
# Gathering Lat/Lng for Zip Code 95823 Index = 79
# Gathering Lat/Lng for Zip Code 95824 Index = 80
# Gathering Lat/Lng for Zip Code 95825 Index = 81
# Gathering Lat/Lng for Zip Code 95826 Index = 82
# Gathering Lat/Lng for Zip Code 95827 Index = 83
# Gathering Lat/Lng for Zip Code 95828 Index = 84
# Gathering Lat/Lng for Zip Code 95829 Index = 85
# Gathering Lat/Lng for Zip Code 95830 Index = 86
# Gathering Lat/Lng for Zip Code 95831 Index = 87
# Gathering Lat/Lng for Zip Code 95832 Index = 88
# Gathering Lat/Lng for Zip Code 95833 Index = 89
# Gathering Lat/Lng for Zip Code 95834 Index = 90
# Gathering Lat/Lng for Zip Code 95835 Index = 91
# Gathering Lat/Lng for Zip Code 95837 Index = 92
# Gathering Lat/Lng for Zip Code 95838 Index = 93
# Gathering Lat/Lng for Zip Code 95841 Index = 94
# Gathering Lat/Lng for Zip Code 95842 Index = 95
# Gathering Lat/Lng for Zip Code 95843 Index = 96
# Gathering Lat/Lng for Zip Code 95864 Index = 97
# Gathering Lat/Lng for Zip Code 95608 Index = 98
# Gathering Lat/Lng for Zip Code 95610 Index = 99
# Gathering Lat/Lng for Zip Code 95621 Index = 100
# Gathering Lat/Lng for Zip Code 95624 Index = 101
# Gathering Lat/Lng for Zip Code 95626 Index = 102
# Gathering Lat/Lng for Zip Code 95628 Index = 103
# Gathering Lat/Lng for Zip Code 95630 Index = 104
# Gathering Lat/Lng for Zip Code 95632 Index = 105
# Gathering Lat/Lng for Zip Code 95638 Index = 106
# Gathering Lat/Lng for Zip Code 95639 Index = 107
# Gathering Lat/Lng for Zip Code 95641 Index = 108
# Gathering Lat/Lng for Zip Code 95655 Index = 109
# Gathering Lat/Lng for Zip Code 95660 Index = 110
# Gathering Lat/Lng for Zip Code 95662 Index = 111
# Gathering Lat/Lng for Zip Code 95670 Index = 112
# Gathering Lat/Lng for Zip Code 95673 Index = 113
# Gathering Lat/Lng for Zip Code 95683 Index = 114
# Gathering Lat/Lng for Zip Code 95690 Index = 115
# Gathering Lat/Lng for Zip Code 95693 Index = 116
# Gathering Lat/Lng for Zip Code 95742 Index = 117
# Gathering Lat/Lng for Zip Code 95758 Index = 118
# Gathering Lat/Lng for Zip Code 95814 Index = 119
# Gathering Lat/Lng for Zip Code 95815 Index = 120
# Gathering Lat/Lng for Zip Code 95816 Index = 121
# Gathering Lat/Lng for Zip Code 95817 Index = 122
# Gathering Lat/Lng for Zip Code 95818 Index = 123
# Gathering Lat/Lng for Zip Code 95819 Index = 124
# Gathering Lat/Lng for Zip Code 95820 Index = 125
# Gathering Lat/Lng for Zip Code 95821 Index = 126
# Gathering Lat/Lng for Zip Code 95822 Index = 127
# Gathering Lat/Lng for Zip Code 95823 Index = 128
# Gathering Lat/Lng for Zip Code 95824 Index = 129
# Gathering Lat/Lng for Zip Code 95825 Index = 130
# Gathering Lat/Lng for Zip Code 95826 Index = 131
# Gathering Lat/Lng for Zip Code 95827 Index = 132
# Gathering Lat/Lng for Zip Code 95828 Index = 133
# Gathering Lat/Lng for Zip Code 95829 Index = 134
# Gathering Lat/Lng for Zip Code 95830 Index = 135
# Gathering Lat/Lng for Zip Code 95831 Index = 136
# Gathering Lat/Lng for Zip Code 95832 Index = 137
# Gathering Lat/Lng for Zip Code 95833 Index = 138
# Gathering Lat/Lng for Zip Code 95834 Index = 139
# Gathering Lat/Lng for Zip Code 95835 Index = 140
# Gathering Lat/Lng for Zip Code 95837 Index = 141
# Gathering Lat/Lng for Zip Code 95838 Index = 142
# Gathering Lat/Lng for Zip Code 95841 Index = 143
# Gathering Lat/Lng for Zip Code 95842 Index = 144
# Gathering Lat/Lng for Zip Code 95843 Index = 145
# Gathering Lat/Lng for Zip Code 95864 Index = 146
# Gathering Lat/Lng for Zip Code 95608 Index = 147
# Gathering Lat/Lng for Zip Code 95610 Index = 148
# Gathering Lat/Lng for Zip Code 95621 Index = 149
# Gathering Lat/Lng for Zip Code 95624 Index = 150
# Gathering Lat/Lng for Zip Code 95626 Index = 151
# Gathering Lat/Lng for Zip Code 95628 Index = 152
# Gathering Lat/Lng for Zip Code 95630 Index = 153
# Gathering Lat/Lng for Zip Code 95632 Index = 154
# Gathering Lat/Lng for Zip Code 95638 Index = 155
# Gathering Lat/Lng for Zip Code 95639 Index = 156
# Gathering Lat/Lng for Zip Code 95641 Index = 157
# Gathering Lat/Lng for Zip Code 95655 Index = 158
# Gathering Lat/Lng for Zip Code 95660 Index = 159
# Gathering Lat/Lng for Zip Code 95662 Index = 160
# Gathering Lat/Lng for Zip Code 95670 Index = 161
# Gathering Lat/Lng for Zip Code 95673 Index = 162
# Gathering Lat/Lng for Zip Code 95683 Index = 163
# Gathering Lat/Lng for Zip Code 95690 Index = 164
# Gathering Lat/Lng for Zip Code 95693 Index = 165
# Gathering Lat/Lng for Zip Code 95742 Index = 166
# Gathering Lat/Lng for Zip Code 95758 Index = 167
# Gathering Lat/Lng for Zip Code 95814 Index = 168
# Gathering Lat/Lng for Zip Code 95815 Index = 169
# Gathering Lat/Lng for Zip Code 95816 Index = 170
# Gathering Lat/Lng for Zip Code 95817 Index = 171
# Gathering Lat/Lng for Zip Code 95818 Index = 172
# Gathering Lat/Lng for Zip Code 95819 Index = 173
# Gathering Lat/Lng for Zip Code 95820 Index = 174
# Gathering Lat/Lng for Zip Code 95821 Index = 175
# Gathering Lat/Lng for Zip Code 95822 Index = 176
# Gathering Lat/Lng for Zip Code 95823 Index = 177
# Gathering Lat/Lng for Zip Code 95824 Index = 178
# Gathering Lat/Lng for Zip Code 95825 Index = 179
# Gathering Lat/Lng for Zip Code 95826 Index = 180
# Gathering Lat/Lng for Zip Code 95827 Index = 181
# Gathering Lat/Lng for Zip Code 95828 Index = 182
# Gathering Lat/Lng for Zip Code 95829 Index = 183
# Gathering Lat/Lng for Zip Code 95830 Index = 184
# Gathering Lat/Lng for Zip Code 95831 Index = 185
# Gathering Lat/Lng for Zip Code 95832 Index = 186
# Gathering Lat/Lng for Zip Code 95833 Index = 187
# Gathering Lat/Lng for Zip Code 95834 Index = 188
# Gathering Lat/Lng for Zip Code 95835 Index = 189
# Gathering Lat/Lng for Zip Code 95837 Index = 190
# Gathering Lat/Lng for Zip Code 95838 Index = 191
# Gathering Lat/Lng for Zip Code 95841 Index = 192
# Gathering Lat/Lng for Zip Code 95842 Index = 193
# Gathering Lat/Lng for Zip Code 95843 Index = 194
# Gathering Lat/Lng for Zip Code 95864 Index = 195
# Gathering Lat/Lng for Zip Code 95608 Index = 196
# Gathering Lat/Lng for Zip Code 95610 Index = 197
# Gathering Lat/Lng for Zip Code 95621 Index = 198
# Gathering Lat/Lng for Zip Code 95624 Index = 199
# Gathering Lat/Lng for Zip Code 95626 Index = 200
# Gathering Lat/Lng for Zip Code 95628 Index = 201
# Gathering Lat/Lng for Zip Code 95630 Index = 202
# Gathering Lat/Lng for Zip Code 95632 Index = 203
# Gathering Lat/Lng for Zip Code 95638 Index = 204
# Gathering Lat/Lng for Zip Code 95639 Index = 205
# Gathering Lat/Lng for Zip Code 95641 Index = 206
# Gathering Lat/Lng for Zip Code 95655 Index = 207
# Gathering Lat/Lng for Zip Code 95660 Index = 208
# Gathering Lat/Lng for Zip Code 95662 Index = 209
# Gathering Lat/Lng for Zip Code 95670 Index = 210
# Gathering Lat/Lng for Zip Code 95673 Index = 211
# Gathering Lat/Lng for Zip Code 95683 Index = 212
# Gathering Lat/Lng for Zip Code 95690 Index = 213
# Gathering Lat/Lng for Zip Code 95693 Index = 214
# Gathering Lat/Lng for Zip Code 95742 Index = 215
# Gathering Lat/Lng for Zip Code 95758 Index = 216
# Gathering Lat/Lng for Zip Code 95814 Index = 217
# Gathering Lat/Lng for Zip Code 95815 Index = 218
# Gathering Lat/Lng for Zip Code 95816 Index = 219
# Gathering Lat/Lng for Zip Code 95817 Index = 220
# Gathering Lat/Lng for Zip Code 95818 Index = 221
# Gathering Lat/Lng for Zip Code 95819 Index = 222
# Gathering Lat/Lng for Zip Code 95820 Index = 223
# Gathering Lat/Lng for Zip Code 95821 Index = 224
# Gathering Lat/Lng for Zip Code 95822 Index = 225
# Gathering Lat/Lng for Zip Code 95823 Index = 226
# Gathering Lat/Lng for Zip Code 95824 Index = 227
# Gathering Lat/Lng for Zip Code 95825 Index = 228
# Gathering Lat/Lng for Zip Code 95826 Index = 229
# Gathering Lat/Lng for Zip Code 95827 Index = 230
# Gathering Lat/Lng for Zip Code 95828 Index = 231
# Gathering Lat/Lng for Zip Code 95829 Index = 232
# Gathering Lat/Lng for Zip Code 95830 Index = 233
# Gathering Lat/Lng for Zip Code 95831 Index = 234
# Gathering Lat/Lng for Zip Code 95832 Index = 235
# Gathering Lat/Lng for Zip Code 95833 Index = 236
# Gathering Lat/Lng for Zip Code 95834 Index = 237
# Gathering Lat/Lng for Zip Code 95835 Index = 238
# Gathering Lat/Lng for Zip Code 95837 Index = 239
# Gathering Lat/Lng for Zip Code 95838 Index = 240
# Gathering Lat/Lng for Zip Code 95841 Index = 241
# Gathering Lat/Lng for Zip Code 95842 Index = 242
# Gathering Lat/Lng for Zip Code 95843 Index = 243
# Gathering Lat/Lng for Zip Code 95864 Index = 244
#    Year  ZipCode  Population  Poverty Count  Poverty Rate  \
# 0  2014    95608     60729.0         8301.0         13.67
# 1  2014    95610     43572.0         7174.0         16.46
# 2  2014    95621     41474.0         5842.0         14.09
# 3  2014    95624     63131.0         6848.0         10.85
# 4  2014    95626      6335.0          792.0         12.50
#
#    Family Poverty Count  Median Household Income  Per Capita Income  \
# 0                1476.0                  55256.0            34606.0
# 1                1136.0                  50536.0            25288.0
# 2                1069.0                  51827.0            24379.0
# 3                1266.0                  80233.0            29752.0
# 4                 182.0                  60579.0            22576.0
#
#    Median Home Value     PC  Crime Rate        Lat         Lng
# 0           304200.0  229.0        0.38  38.627279 -121.319849
# 1           217100.0    2.0        0.00  38.697745 -121.274081
# 2           173700.0   10.0        0.02  38.694001 -121.302688
# 3           270400.0    0.0        0.00  38.424402 -121.331288
# 4           193900.0    5.0        0.08  38.719089 -121.457045

# %%
# Write out the Data Frames
merged_all_df.to_csv("./Resources/merged_all_lat_lng_df.csv")
merged_personal_df.to_csv("./Resources/merged_personal_lat_lng_df.csv")

# %%
# Prep data frames for a heatmap
merged_all_2014_df = merged_all_df.loc[merged_all_df["Year"] == 2014]
merged_all_2014_lat_lng_df = merged_all_2014_df[["Lat", "Lng"]].astype(float)
merged_all_2014_max_poverty_rate = merged_all_2014_df["Poverty Rate"].max()
merged_all_2014_max_crime_rate = merged_all_2014_df["Crime Rate"].max()
print(f"Max Poverty Rate is {merged_all_2014_max_poverty_rate}")
print(f"Max Crime Rate is {merged_all_2014_max_crime_rate}")
# Out:
# Max Poverty Rate is 39.24
# Max Crime Rate is 37.72

# %%
# Create the Poverty Rate heatmap for 2014
fig = gmaps.figure(center=(38.55, -121.0), zoom_level=10)
heatmap_layer = gmaps.heatmap_layer(merged_all_2014_lat_lng_df, weights=merged_all_2014_df["Poverty Rate"], max_intensity=40,
                                    point_radius=0.03, dissipating=False, opacity=0.5)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the Crime Rate heatmap for 2014
fig = gmaps.figure(center=(38.55, -121.0), zoom_level=10)
heatmap_layer = gmaps.heatmap_layer(merged_all_2014_lat_lng_df, weights=merged_all_2014_df["Crime Rate"], max_intensity=10,
                                    point_radius=0.03, dissipating=False, opacity=0.5)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
